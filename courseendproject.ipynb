# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('./1585898503_datasets/loan_data.csv')

# %%
df
# Out:
#       credit.policy             purpose  int.rate  installment  \
# 0                 1  debt_consolidation    0.1189       829.10
# 1                 1         credit_card    0.1071       228.22
# 2                 1  debt_consolidation    0.1357       366.86
# 3                 1  debt_consolidation    0.1008       162.34
# 4                 1         credit_card    0.1426       102.92
# ...             ...                 ...       ...          ...
# 9573              0           all_other    0.1461       344.76
# 9574              0           all_other    0.1253       257.70
# 9575              0  debt_consolidation    0.1071        97.81
# 9576              0    home_improvement    0.1600       351.58
# 9577              0  debt_consolidation    0.1392       853.43
#
#       log.annual.inc    dti  fico  days.with.cr.line  revol.bal  revol.util  \
# 0          11.350407  19.48   737        5639.958333      28854        52.1
# ...

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# ...

# %%
df.shape
# Out:
# (9578, 14)

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df['purpose'].unique()
# Out:
# array(['debt_consolidation', 'credit_card', 'all_other',
#        'home_improvement', 'small_business', 'major_purchase',
#        'educational'], dtype=object)

# %%
df['not.fully.paid'].value_counts()
# Out:
# 0    8045
# 1    1533
# Name: not.fully.paid, dtype: int64

# %%
sns.countplot(x=df['not.fully.paid'])
# Out:
# <AxesSubplot: xlabel='not.fully.paid', ylabel='count'>

# %%
sns.countplot(x=df['purpose'])
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'debt_consolidation'),
#   Text(1, 0, 'credit_card'),
#   Text(2, 0, 'all_other'),
#   Text(3, 0, 'home_improvement'),
#   Text(4, 0, 'small_business'),
#   Text(5, 0, 'major_purchase'),
#   Text(6, 0, 'educational')])

# %%
#handle Imbalanced Data
not_fully_paid0=df[df['not.fully.paid']==0]
not_fully_paid1=df[df['not.fully.paid']==1]

# %%
#resample
from sklearn.utils import resample
df_sampled_data=resample(not_fully_paid1,replace=True,n_samples=8045)

# %%
df_sampled_data.shape
# Out:
# (8045, 14)

# %%
new_df=pd.concat([not_fully_paid0,df_sampled_data])

# %%
from sklearn.utils import shuffle
new_df=shuffle(new_df)

# %%
new_df.shape
# Out:
# (16090, 14)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in new_df.columns:
    if new_df[i].dtypes=='object':
        new_df[i]=le.fit_transform(new_df[i])

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16090 entries, 9201 to 8870
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      16090 non-null  int64
#  1   purpose            16090 non-null  int32
#  2   int.rate           16090 non-null  float64
#  3   installment        16090 non-null  float64
#  4   log.annual.inc     16090 non-null  float64
#  5   dti                16090 non-null  float64
#  6   fico               16090 non-null  int64
#  7   days.with.cr.line  16090 non-null  float64
#  8   revol.bal          16090 non-null  int64
#  9   revol.util         16090 non-null  float64
#  10  inq.last.6mths     16090 non-null  int64
#  11  delinq.2yrs        16090 non-null  int64
#  12  pub.rec            16090 non-null  int64
#  13  not.fully.paid     16090 non-null  int64
# dtypes: float64(6), int32(1), int64(7)
# memory usage: 1.8 MB

# %%
le.classes_
# Out:
# array(['all_other', 'credit_card', 'debt_consolidation', 'educational',
#        'home_improvement', 'major_purchase', 'small_business'],
#       dtype=object)

# %%
le.get_params
# Out:
# <bound method BaseEstimator.get_params of LabelEncoder()>

# %%
plt.figure(figsize=(15,15))
sns.heatmap(new_df.corr(),annot=True)
plt.show()

# %%
new_df.corr().abs()['not.fully.paid'].sort_values(ascending=False)
# Out:
# not.fully.paid       1.000000
# int.rate             0.220045
# fico                 0.209711
# credit.policy        0.194123
# inq.last.6mths       0.173261
# revol.util           0.116913
# installment          0.074307
# purpose              0.071305
# revol.bal            0.066255
# pub.rec              0.065165
# dti                  0.052041
# days.with.cr.line    0.035256
# log.annual.inc       0.032543
# delinq.2yrs          0.008925
# Name: not.fully.paid, dtype: float64

# %%
new_df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
x=new_df[['credit.policy', 'purpose', 'int.rate', 'installment','fico', 'revol.bal', 'revol.util','inq.last.6mths','pub.rec']]

# %%
x.shape
# Out:
# (16090, 9)

# %%
y=new_df[['not.fully.paid']]

# %%
y.shape
# Out:
# (16090, 1)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#apply standardScaler
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.fit_transform(xtest)

# %%
# build the predictive models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping

model =Sequential()

# %%
#first Layer
model.add(Dense(19,activation='relu',input_shape=(9,)))
#dropout is used to handle overfitting
model.add(Dropout(0.3))
#Add second Layer
model.add(Dense(10,activation='relu'))
model.add(Dropout(0.3))
#output layer
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 19)                190
#
#  dense_1 (Dense)             (None, 19)                380
#
#  dropout (Dropout)           (None, 19)                0
#
#  dense_2 (Dense)             (None, 10)                200
#
#  dropout_1 (Dropout)         (None, 10)                0
#
#  dense_3 (Dense)             (None, 2)                 22
#
#  dense_4 (Dense)             (None, 19)                57
#
#  dropout_2 (Dropout)         (None, 19)                0
#
#  dense_5 (Dense)             (None, 10)                200
#
#  dropout_3 (Dropout)         (None, 10)                0
#
#  dense_6 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1,060
# Trainable params: 1,060
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#early stopping

early_stop=EarlyStopping(monitor='val_loss',min_delta=0.01,mode='min',verbose=1,patience=10)

# %%
history=model.fit(xtrain,ytrain,epochs=50,batch_size=256,validation_data=(xtest,ytest),callbacks=[early_stop])
# Out:
# Epoch 1/50
# 51/51 [==============================] - 4s 12ms/step - loss: 0.6944 - accuracy: 0.4962 - val_loss: 0.6931 - val_accuracy: 0.4901
# Epoch 2/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6907 - accuracy: 0.5203 - val_loss: 0.6836 - val_accuracy: 0.5963
# Epoch 3/50
# 51/51 [==============================] - 1s 10ms/step - loss: 0.6824 - accuracy: 0.5531 - val_loss: 0.6687 - val_accuracy: 0.6175
# Epoch 4/50
# 51/51 [==============================] - 0s 8ms/step - loss: 0.6756 - accuracy: 0.5728 - val_loss: 0.6604 - val_accuracy: 0.6184
# Epoch 5/50
# 51/51 [==============================] - 0s 6ms/step - loss: 0.6692 - accuracy: 0.5931 - val_loss: 0.6545 - val_accuracy: 0.6175
# Epoch 6/50
# 51/51 [==============================] - 0s 5ms/step - loss: 0.6634 - accuracy: 0.5979 - val_loss: 0.6500 - val_accuracy: 0.6249
# Epoch 7/50
# ...

# %%
model.evaluate(xtest,ytest)
# Out:
# 101/101 [==============================] - 0s 2ms/step - loss: 0.6406 - accuracy: 0.6283
# [0.6405528783798218, 0.6283406019210815]

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 403/403 [==============================] - 1s 2ms/step - loss: 0.6335 - accuracy: 0.6443
# [0.6334815621376038, 0.6443443298339844]

# %%
#plot the accuracy and loss
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(['train','test'],loc='best')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend(['train','test'],loc='best')
plt.show()
